# %%
import pandas as pd

# %%
df = pd.read_csv("../data/world_cities.csv")

# %%
df['complete_name'] = df['name'].astype(str) + ', ' + df['subcountry'].astype(str) + ', ' + df['country'].astype(str)

# %%
df
# Out:
#                     name               country           subcountry  \
# 0           les Escaldes               Andorra   Escaldes-Engordany
# 1       Andorra la Vella               Andorra     Andorra la Vella
# 2         Umm al Qaywayn  United Arab Emirates       Umm al Qaywayn
# 3         Ras al-Khaimah  United Arab Emirates      Raʼs al Khaymah
# 4           Khawr Fakkān  United Arab Emirates         Ash Shāriqah
# 5                  Dubai  United Arab Emirates                Dubai
# 6      Dibba Al-Fujairah  United Arab Emirates          Al Fujayrah
# 7          Dibba Al-Hisn  United Arab Emirates          Al Fujayrah
# 8                Sharjah  United Arab Emirates         Ash Shāriqah
# 9              Ar Ruways  United Arab Emirates            Abu Dhabi
# 10           Al Fujayrah  United Arab Emirates          Al Fujayrah
# 11                Al Ain  United Arab Emirates            Abu Dhabi
# 12                 Ajman  United Arab Emirates                Ajman
# ...
